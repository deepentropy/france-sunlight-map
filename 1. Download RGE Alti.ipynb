# %%
import pandas as pd
import requests
from tqdm import tqdm
# reload imports
# %load_ext autoreload
# %autoreload 2
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"

# %%
links_file = 'geoservices/rgealti_links.txt'
with open(links_file, 'r') as f:
    links = f.read().splitlines()

len(links)
# Out:
# 302

# %%
# https://data.geopf.fr/telechargement/download/RGEALTI/RGEALTI_2-0_1M_ASC_WGS84UTM20-MART87_D972_2015-10-21/RGEALTI_2-0_1M_ASC_WGS84UTM20-MART87_D972_2015-10-21.7z
# https://data.geopf.fr/telechargement/download/RGEALTI/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D001_2023-08-08/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D001_2023-08-08.7z

parsed = []
for link in links:
    parts = link.split('/')[-1].split('_')
    resolution = parts[2][0]
    department = parts[5]
    parsed.append([resolution, department, link])

df_links = pd.DataFrame(parsed, columns=['resolution', 'department', 'link'])
df_links
# Out:
#     resolution department                                               link
# 0            1       D001  https://data.geopf.fr/telechargement/download/...
# 1            1       D001  https://data.geopf.fr/telechargement/download/...
# 2            1       D002  https://data.geopf.fr/telechargement/download/...
# 3            1       D002  https://data.geopf.fr/telechargement/download/...
# 4            1       D003  https://data.geopf.fr/telechargement/download/...
# ..         ...        ...                                                ...
# 297          5       D093  https://data.geopf.fr/telechargement/download/...
# 298          5       D094  https://data.geopf.fr/telechargement/download/...
# 299          5       D095  https://data.geopf.fr/telechargement/download/...
# 300          5       D02A  https://data.geopf.fr/telechargement/download/...
# 301          5       D02B  https://data.geopf.fr/telechargement/download/...
#
# [302 rows x 3 columns]

# %%
# python
import os
import glob
import subprocess
from pathlib import Path
from typing import List, Optional

def _merge_parts(parts: List[Path], out_path: Path) -> None:
    out_path.parent.mkdir(parents=True, exist_ok=True)
    with out_path.open("wb") as fout:
        for p in parts:
            with p.open("rb") as fin:
                while True:
                    chunk = fin.read(1024 * 1024)
                    if not chunk:
                        break
                    fout.write(chunk)

def _extract_with_py7zr(archive: Path, out_dir: Path) -> None:
    try:
        import py7zr
        with py7zr.SevenZipFile(str(archive), mode="r") as z:
            z.extractall(path=str(out_dir))
        return
    except Exception as e:
        raise RuntimeError(f"py7zr failed: {e}")

def _extract_with_7z(archive: Path, out_dir: Path) -> None:
    # Attends que 7z (7z.exe) soit dans le PATH sur Windows
    subprocess.run(["7z", "x", str(archive), f"-o{str(out_dir)}", "-y"], check=True)

def extract_archive_from_folder(folder: str, out_dir: Optional[str] = None) -> Path:
    """
    Détecte et extrait une archive 7z ou ses parties dans `folder`.
    Retourne le chemin du dossier d'extraction.
    """
    folder_p = Path(folder)
    if out_dir:
        out_p = Path(out_dir)
    else:
        out_p = folder_p / "extracted"
    out_p.mkdir(parents=True, exist_ok=True)

    # 1) Cherche un fichier .7z complet
    sevenz = sorted(folder_p.glob("*.7z"))
    if sevenz:
        print(f"Found {len(sevenz)} .7z archives.")
        for archive in sevenz:
            folder = archive.stem
            # exist
            if (out_p / folder).exists():
                #print(f"Skipping extraction of {archive}, output folder already exists.")
                continue
            print(f"Extracting {archive}...")
            try:
                _extract_with_py7zr(archive, out_p)
            except Exception:
                _extract_with_7z(archive, out_p)
        return out_p

    # 2) Cherche .7z.001 (nom complet comme name.7z.001)
    parts_7z001 = sorted(folder_p.glob("*.7z.001"))
    if parts_7z001:
        first = parts_7z001[0]
        try:
            _extract_with_7z(first, out_p)
            return out_p
        except subprocess.CalledProcessError:
            # fallback: merge puis extract
            merged = folder_p / "merged.7z"
            all_parts = sorted(folder_p.glob(f"{first.stem.split('.7z')[0]}*.7z.*")) or parts_7z001
            _merge_parts(all_parts, merged)
            try:
                _extract_with_py7zr(merged, out_p)
            except Exception:
                _extract_with_7z(merged, out_p)
            finally:
                if merged.exists():
                    merged.unlink()
            return out_p

    # 3) Cherche parties generiques .001/.002...
    parts_001 = sorted(folder_p.glob("*.001"))
    if parts_001:
        try:
            _extract_with_7z(parts_001[0], out_p)
            return out_p
        except subprocess.CalledProcessError:
            merged = folder_p / "merged.7z"
            _merge_parts(parts_001, merged)
            try:
                _extract_with_py7zr(merged, out_p)
            except Exception:
                _extract_with_7z(merged, out_p)
            finally:
                if merged.exists():
                    merged.unlink()
            return out_p

    raise FileNotFoundError(f"Aucune archive 7z ni parties trouvées dans ` {folder} `")

# %%
def download_with_ua_progress(url: str, out_dir: str, user_agent: str = None, timeout: int = 30, chunk_size: int = 8192) -> str:
    os.makedirs(out_dir, exist_ok=True)
    local_path = os.path.join(out_dir, os.path.basename(url))
    if os.path.exists(local_path):
        print(f'File {local_path} already exists, skipping download.')
        return local_path
    headers = {'User-Agent': user_agent or "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}
    with requests.get(url, headers=headers, stream=True, timeout=timeout) as r:
        r.raise_for_status()
        total = int(r.headers.get('content-length') or 0)
        total_for_tqdm = total if total > 0 else None
        with open(local_path, 'wb') as f, tqdm(total=total_for_tqdm, unit='B', unit_scale=True, unit_divisor=1024, desc=os.path.basename(local_path)) as bar:
            for chunk in r.iter_content(chunk_size=chunk_size):
                if not chunk:
                    continue
                f.write(chunk)
                bar.update(len(chunk))
    return local_path

# %%
resolution = '5'
#department = 'D074'
departments = df_links[df_links['resolution'] == resolution]['department'].unique().tolist()

# %%
output_dir = f'D:/RGEALTI/'
os.makedirs(output_dir, exist_ok=True)
links = df_links[(df_links['resolution'] == resolution)]['link'].tolist()
for link in links:
    filename = link.split('/')[-1]
    if os.path.exists(os.path.join(output_dir, filename)):
        #print(f'File {filename} already exists, skipping download.')
        continue
    print(f'Downloading {link}')

    download_with_ua_progress(link, output_dir, user_agent)
    #extract_archive_from_folder(output_dir, output_dir)
# Out:
# Downloading https://data.geopf.fr/telechargement/download/RGEALTI/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D043_2022-10-03/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D043_2022-10-03.7z
# RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D043_2022-10-03.7z: 100%|██████████| 500M/500M [02:59<00:00, 2.93MB/s]
# Downloading https://data.geopf.fr/telechargement/download/RGEALTI/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D046_2019-10-17/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D046_2019-10-17.7z
# RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D046_2019-10-17.7z: 100%|██████████| 328M/328M [01:58<00:00, 2.91MB/s]
# Downloading https://data.geopf.fr/telechargement/download/RGEALTI/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D075_2020-07-30/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D075_2020-07-30.7z
# RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D075_2020-07-30.7z: 100%|██████████| 13.3M/13.3M [00:00<00:00, 22.6MB/s]
# Downloading https://data.geopf.fr/telechargement/download/RGEALTI/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D078_2020-07-30/RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D078_2020-07-30.7z
# RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D078_2020-07-30.7z: 100%|██████████| 86.5M/86.5M [00:02<00:00, 40.9MB/s]

# %%
extract_archive_from_folder(output_dir, output_dir)
# Out:
# Found 96 .7z archives.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D001_2023-08-08.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D002_2020-09-04.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D003_2023-08-10.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D004_2023-08-08.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D005_2020-10-14.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D006_2023-08-08.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D007_2022-12-16.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D008_2019-10-14.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D009_2023-10-04.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D010_2021-11-04.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D011_2023-10-04.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D012_2022-09-29.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D013_2022-12-16.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D014_2022-12-21.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D015_2022-09-29.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D016_2023-07-28.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D017_2023-07-28.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D018_2023-01-03.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D019_2019-09-09.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D021_2023-08-08.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D022_2022-10-14.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D023_2019-11-20.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D024_2019-10-17.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D025_2021-01-13.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D026_2022-12-16.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D027_2022-12-21.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D028_2019-12-16.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D029_2022-10-14.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D030_2022-12-16.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D031_2021-05-12.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D032_2019-11-21.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D033_2021-04-19.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D034_2022-12-16.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D035_2022-11-15.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D036_2022-09-28.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D037_2023-07-20.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D038_2020-11-13.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D039_2023-08-08.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D040_2021-04-19.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D041_2019-12-16.7z, output folder already exists.
# Skipping extraction of D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D042_2023-08-10.7z, output folder already exists.
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D043_2022-10-03.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D044_2022-12-20.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D045_2023-01-03.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D046_2019-10-17.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D047_2019-11-21.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D048_2022-12-16.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D049_2023-01-12.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D050_2022-12-21.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D051_2019-10-14.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D052_2021-01-13.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D053_2023-01-12.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D054_2021-09-24.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D055_2018-12-07.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D056_2022-12-15.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D057_2021-09-24.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D058_2023-08-01.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D059_2021-09-20.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D060_2020-09-04.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D061_2023-01-12.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D062_2021-09-20.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D063_2021-01-22.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D064_2021-04-19.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D065_2020-02-11.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D066_2023-10-04.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D067_2021-11-02.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D068_2021-11-02.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D069_2023-08-10.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D070_2021-01-13.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D071_2023-08-10.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D072_2023-01-12.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D073_2020-10-15.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D074_2020-10-15.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D075_2020-07-30.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D076_2020-10-20.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D077_2021-03-03.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D078_2020-07-30.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D079_2023-08-10.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D080_2019-07-09.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D081_2022-07-29.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D082_2019-10-30.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D083_2022-12-05.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D084_2022-12-16.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D085_2023-07-28.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D086_2023-08-10.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D087_2021-10-26.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D088_2021-11-02.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D089_2023-01-03.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D090_2021-01-13.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D091_2021-03-03.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D092_2020-07-30.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D093_2020-07-30.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D094_2020-07-30.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN69_D095_2020-07-30.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN78C_D02A_2020-04-16.7z...
# Extracting D:\RGEALTI\RGEALTI_2-0_5M_ASC_LAMB93-IGN78C_D02B_2020-04-16.7z...
# WindowsPath('D:/RGEALTI')

# %%
print('Combining all departments into a single npz file...')
data = mnf.merge_npy_files(input_dir='npy',output_path='D:\\all_departments.npy')

# %%
data

# %%
from compute import BatchProcessor
from datetime import datetime

processor = BatchProcessor()

daylight = processor.process_from_npz(
    input_npz=data,
    output_npz='D:\\daylight_results.npz',
    date=datetime(2024, 6, 21),  # Summer solstice
    batch_size=240,               # Adjust for your GPU memory
    pixel_size=5.0,               # 5 meters for 5M resolution data
    lat_center=46.0,              # France center latitude
    lon_center=2.0                # France center longitude
)

print(f'Computed daylight for {len(daylight)} tiles')
